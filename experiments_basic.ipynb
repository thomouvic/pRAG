# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances
from scipy.spatial.distance import cdist
from scipy.spatial.distance import cosine

# %%
def load_glove_embeddings(file_path):
    embeddings = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = list(map(float, values[1:]))
            embeddings[word] = vector
    return embeddings

# Path to the GloVe file
glove_file_path = 'glove.6B.300d.txt'

# Load the embeddings
embeddings = load_glove_embeddings(glove_file_path)

# Get the embedding for "norway"
norway_embedding = embeddings.get('norway')

if norway_embedding:
    print("Embedding for 'norway':")
    print(norway_embedding)
else:
    print("'norway' not found in embeddings.")
# Out:
# Embedding for 'norway':
# [-0.10675, 0.1479, -0.50551, 0.47089, 0.3117, 0.15165, 0.19078, 0.27304, -0.024549, -1.2821, -0.21861, -0.39795, 0.22596, 0.30201, -0.33422, 0.25108, 0.32763, 0.39699, -0.71871, 0.0096784, 0.11126, 0.099761, -0.27434, 0.40397, -0.3468, -0.11817, -0.3358, -0.47028, -1.0238, -0.022385, -0.19229, -0.51256, 0.13575, 0.42843, -0.29873, -0.39356, 0.57573, -0.11213, -0.26791, 0.28042, -0.88649, -0.085926, 0.17979, -0.23622, -0.40873, -0.38531, 0.3385, -0.20835, 0.18581, 0.015005, -0.64442, 0.2628, 0.35952, -0.41501, -0.322, 0.68475, -0.22952, 0.10886, -0.2761, 0.35901, -0.81549, 0.94224, -0.31344, -0.43145, 0.25273, 0.055572, -0.099283, 0.55193, 0.44542, -0.20776, -0.90083, -0.19906, 0.26436, 0.064958, -0.47981, 0.11094, -0.085895, -0.052858, 0.31741, 0.10706, 0.13175, -0.61744, -0.33871, 0.176, 0.32555, -0.30336, -0.10891, -0.37193, -0.21215, -0.96199, -0.088204, -0.33672, 0.25825, -0.13834, 0.012352, -0.68369, 0.10282, 0.094525, -0.57033, 0.28754, 0.10308, -0.28742, 0.37831, -0.57484, 0.38251, -0.15269, 0.66628, 0.34187, -0.3091, 0.68724, -0.057327, -0.10411, -0.25353, -0.19327, 0.17894, -0.31704, -0.10324, 0.013705, -0.32307, 0.015043, -0.37639, -0.2268, 0.29881, -0.24655, 0.47556, 0.75957, 0.065319, 0.06667, 0.57339, -0.16068, -0.19323, 0.028777, -0.49365, -0.35707, 0.45901, 0.37442, -0.36011, 0.69996, -0.34825, 0.085928, 0.26405, 0.15215, -0.098711, -0.28948, -0.0032701, 0.12993, 0.95741, 0.25186, 0.10945, -0.63993, -0.24089, -0.015973, 0.020604, -0.071779, -0.54337, 0.038777, 0.12411, 0.096053, -0.19151, -0.097226, -0.41518, 0.67377, 0.37881, -0.019961, 0.14578, 0.92356, 0.18574, -0.14701, 0.0064321, -0.50451, 0.1642, 0.19816, -0.11672, 0.018089, 0.26912, 0.3133, 0.66926, -0.11582, -0.52952, 1.0097, -0.35299, 0.18963, -0.071632, -0.57368, 0.67244, -0.2465, -0.83105, -0.49249, -0.8175, -0.066909, 0.33319, -0.50199, 0.56591, -0.14658, 0.065858, -0.29332, 0.016897, 0.03291, 0.36638, -0.1294, 1.0281, -0.65031, -0.51838, -0.05104, 0.10332, -0.23797, -0.5215, 0.12393, 0.26424, -0.18725, -0.26212, 0.056338, 0.10258, 0.328, -0.44208, -0.084597, -0.032575, 0.021393, -0.20567, -0.31069, 0.60652, -0.15914, -0.25313, -0.49962, 0.37238, -0.17352, 0.10454, -0.6276, 0.29351, -0.05378, -0.26994, -0.41159, -0.09153, 0.51266, 0.36764, 0.21354, -0.22744, 0.48, 0.20269, -0.17137, -0.29642, 0.26649, 0.50707, 0.17916, -0.10243, 0.42246, 0.53967, -0.096255, -0.51184, -0.31951, -0.9743, -0.19773, 0.31191, -0.12134, 0.2159, -0.25966, 0.17381, -0.10063, -0.24791, -0.37197, 0.30997, -0.51714, 0.13962, -0.23558, -0.17838, -0.26896, 0.10392, -0.82538, 0.65112, -0.66302, 0.307, -0.56694, 0.19412, 0.32779, -0.065404, -0.30615, -0.8858, -0.63657, 0.89261, -0.07, 0.03784, 0.48304, -0.32974, 0.10076, 0.16009, 0.096503, -0.28587, 0.56273, 0.37293, 0.043231, -0.51599, 0.39658, -0.61284, -0.50459, 0.18009, 0.72474, 0.74185, -0.21289, 0.29131, -0.039123]

# %%
def normalize_embeddings(embeddings):
    normalized_embeddings = {}
    for word, vector in embeddings.items():
        norm = np.linalg.norm(vector)
        if norm > 0:
            normalized_vector = vector / norm
            normalized_embeddings[word] = normalized_vector
    return normalized_embeddings

normalized_embeddings = normalize_embeddings(embeddings)

# Get the embedding for "norway"
norway_embedding = normalized_embeddings.get('norway')
# print(norway_embedding)

# %%
def get_top_similarities(target_word, word_list, embeddings, top_n=20):
    target_embedding = embeddings.get(target_word)
    if target_embedding is None:
        return None

    similarities = {}
    for word in word_list:
        word_embedding = embeddings.get(word)
        if word_embedding is not None:
            similarities[word] = 1 - cosine(target_embedding, word_embedding)

    sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
    return sorted_similarities[:top_n]

# Test the function
european_countries = [
    'albania', 'andorra', 'austria', 'belarus', 'belgium', 'bosnia', 'bulgaria', 'croatia',
    'cyprus', 'czech', 'denmark', 'estonia', 'finland', 'france', 'germany', 'greece',
    'hungary', 'iceland', 'ireland', 'italy', 'latvia', 'liechtenstein', 'lithuania',
    'luxembourg', 'malta', 'moldova', 'monaco', 'montenegro', 'netherlands', 'north macedonia',
    'norway', 'poland', 'portugal', 'romania', 'russia', 'san marino', 'serbia', 'slovakia',
    'slovenia', 'spain', 'sweden', 'switzerland', 'turkey', 'ukraine', 'united kingdom', 'vatican'
]

top_20_similarities = get_top_similarities('norway', european_countries, normalized_embeddings)
print(top_20_similarities)
# Out:
# [('norway', 1), ('denmark', 0.6980988523058034), ('sweden', 0.6567031150559826), ('iceland', 0.6321000420842228), ('finland', 0.6197740583127542), ('netherlands', 0.49975032779171835), ('estonia', 0.49594574438870165), ('switzerland', 0.49237581412474896), ('austria', 0.4910478696010585), ('lithuania', 0.4776603139255837), ('germany', 0.47481855105552884), ('latvia', 0.4747955043159663), ('poland', 0.44408460155662943), ('hungary', 0.4434215764866545), ('bulgaria', 0.4430403688270663), ('portugal', 0.4363678236887445), ('slovakia', 0.4297746516021328), ('belgium', 0.41912721993294366), ('liechtenstein', 0.40841938161504554), ('luxembourg', 0.4071672836820489)]

# %%
# read world_cities.csv
world_cities = pd.read_csv('world_cities.csv')
# lowercase the city names
world_cities['city'] = world_cities['city'].str.lower()
world_cities.head()
# Out:
#         city
# 0      tokyo
# 1    jakarta
# 2      delhi
# 3  guangzhou
# 4     mumbai

# %%
# convert the city names to a list
city_list = world_cities['city'].tolist()

top_20_similarities = get_top_similarities('dhaka', city_list, normalized_embeddings)
print(top_20_similarities)
# Out:
# [('dhaka', 1), ('lahore', 0.6045195884667484), ('delhi', 0.5801741189727798), ('kathmandu', 0.5767808345438777), ('karachi', 0.5673440561332525), ('kolkata', 0.5412403045629106), ('sylhet', 0.5246002691956407), ('hyderabad', 0.5140027152100624), ('rajshahi', 0.5130482827425025), ('harare', 0.5125273361371179), ('khulna', 0.5081745278471346), ('multan', 0.5008812303132791), ('bangalore', 0.4937680822881667), ('peshawar', 0.4899602890251177), ('bangkok', 0.489741201151789), ('mymensingh', 0.47754347426052635), ('johannesburg', 0.4765021598599348), ('ahmedabad', 0.47437400329212487), ('lucknow', 0.4700376385918963), ('rawalpindi', 0.46969229529531953)]

# %% [markdown]
# This function performs K-means clustering on a given set of word embeddings to group them into a specified number of clusters.
# It uses the K-means algorithm to cluster the remaining vectors.
# Each word is then assigned to a cluster based on the K-means output.
# The function returns a dictionary where each key is a cluster label and each value is a list of words belonging to that cluster.
# In the example usage, the function is applied to a subset of the embeddings that correspond to city names, and the resulting clusters are printed.

# %%
def cluster_embeddings(embeddings, num_clusters):
    # Filter out None embeddings and convert to list of vectors
    words = [word for word in embeddings if embeddings[word] is not None]
    vectors = [embeddings[word] for word in words]
    
    # Perform K-means clustering
    kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)
    kmeans.fit(vectors)
    
    # Assign each word to a cluster
    clusters = {}
    for i, label in enumerate(kmeans.labels_):
        if label not in clusters:
            clusters[label] = []
        clusters[label].append(words[i])
    
    return clusters

# Filter embeddings to include only cities
city_embeddings = {city: normalized_embeddings[city] for city in city_list if city in normalized_embeddings}

# Example usage
num_clusters = 100  # Change this to the desired number of clusters
clusters = cluster_embeddings(city_embeddings, num_clusters)

# Print clusters
for label, words in clusters.items():
    print(f"Cluster {label}: {', '.join(words)}")
# Out:
# Cluster 69: tokyo, osaka, nagoya, yokohama, fukuoka, sapporo, kawasaki, kobe, kyoto, saitama, hiroshima, sendai, chiba, sakai, niigata, kumamoto, shizuoka, adachi, kawaguchi, ichikawa, oita, kanazawa, fukuyama, kashiwa, aomori, toyama, nagasaki, gifu, miyazaki, saki, okazaki, nagano, nara, nakano, akita, morioka, fukushima, ibaraki, mito, ichihara, fukui, hiratsuka, soka, yamagata, fuji, matsumoto, ota, arakawa, yamaguchi, hino, sakura, hitachi, iwata, matsuzaka, noda, ueda, dawei, fujita, ashikaga, koga, narita, saida, iizuka, sano, tokai, komatsu, ikeda, shibuya, sakata, iida, shibata, wako, nikko, miki, yoshikawa, tanabe, kashima, saiki, asahi, ito, hashimoto, oda, shirakawa, murakami, mizuho, sakurai, izumi, takeo, yuki, nakagawa, hamada, midori, hikari, ono, takashima, kikuchi, masuda, kobayashi, kasai, miura, kato, ozu, masaki, tamura, goto, shinjo, chuo, takahashi, yoshida, maki, saito, manga, ogawa, nagai, tosa, onda, ishii, aso, oji, sanga, kitajima, furukawa, murayama, matsuura, showa, yosano, shimomura, taku, yoshimi, mori, kawai, arai, mifune, tohoku, aki, haga, yamada, miho, lotte, ishikawa, shinto, hatoyama, yamato, kaji, yoko, yamamoto, yuasa, nishi, iwai, nakayama, murata, mochizuki, nana, jiji, shimizu, yui, hata, gamba, taro
# Cluster 7: jakarta, surabaya, medan, malang, tangerang, semarang, palembang, makassar, bogor, pekanbaru, padang, denpasar, samarinda, banjarmasin, jambi, pontianak, surakarta, kupang, manado, bandung, yogyakarta, jayapura, mataram, palu, bengkulu, ambon, kuching, bali, dili, ternate, lhokseumawe, papeete, manokwari, nabire, tual, honiara, phuket, wamena, meulaboh, bambang, poso, banda, batavia, sumba
# Cluster 90: delhi, mumbai, kolkata, bangalore, chennai, hyderabad, pune, ahmedabad, surat, lucknow, jaipur, kanpur, nagpur, ghaziabad, vadodara, rajkot, indore, thane, bhopal, patna, bilaspur, ludhiana, agra, madurai, jamshedpur, nasik, faridabad, meerut, jabalpur, kalyan, varanasi, aurangabad, dhanbad, amritsar, aligarh, guwahati, ranchi, gwalior, chandigarh, vijayawada, jodhpur, raipur, kota, bareilly, coimbatore, solapur, hubli, owerri, moradabad, klang, gurgaon, jalandhar, ipoh, patiala, thiruvananthapuram, enugu, saharanpur, warangal, kochi, gorakhpur, guntur, bhavnagar, noida, bhilai, mangalore, kuantan, cuttack, kottayam, asansol, kolhapur, ajmer, nanded, amravati, bikaner, agartala, ujjain, jhansi, vellore, jammu, jamnagar, gaya, jalgaon, melaka, udaipur, mathura, sangli, calicut, akola, seremban, bhagalpur, quilon, kakinada, cantonment, bharatpur, rajahmundry, bijapur, rampur, junagadh, hisar, fatehpur, bihar, darbhanga, tirupati, imphal, rewa, pali, haridwar, porbandar, batu, secunderabad, bhuj, ambala, shimla, puri, satara, silchar, dibrugarh, jorhat, shillong, darjeeling, rishikesh, dhar, goa, faizabad, chidambaram, vrindavan, lautoka, diu, bokaro, murshidabad, qadian, pilani, dwarka, allahabad, shirdi, ahmadabad, nagar, khajuraho, tirumala, ghat, baroda, mandal, panjab, sabha
# Cluster 68: guangzhou, shanghai, shenzhen, chengdu, xi'an, chongqing, dongguan, tianjin, wuhan, hangzhou, foshan, quanzhou, nanjing, shenyang, zhanjiang, dalian, qingdao, pudong, zhengzhou, jinan, suzhou, zhangzhou, guilin, changsha, kunming, changchun, urumqi, shantou, hefei, liuzhou, shijiazhuang, ningbo, fuzhou, taiyuan, nanning, harbin, xiamen, wenzhou, changzhou, nanchang, hohhot, tangshan, anshan, guiyang, wuxi, qinhuangdao, lanzhou, zhongshan, weihai, haikou, yantai, huizhou, xining, zhuhai, baoshan, jilin, nantong, yinchuan, beihai, sanya, lhasa
# Cluster 97: manila, beijing, tehran, singapore, washington, dubai, pyongyang, jerusalem, vladimir, drug, guantanamo, enterprise, arafat, erode, surprise, aware, duma, independence, bahrain, xinhua, solana, mission, lebanon, palin, union, naval, tactic, gay, clinton, jordan, media, ire, deal, police, anew, banning, central, gates, obama, dole, summit, march, alliance, unity, middle, schroeder, liberal, fate, hun, republic, palestine, parole, sharon, southeast, loyalist, sake, defiance, peer, federal, tone, powell, wake, pushing, cheney, justice, grave, penal, commerce, dire, ban, bank, bind, progress, friendly, multi, china, has, gore, grants, august, economy, nato, hope, annan, fully, arab
# Cluster 25: seoul, cairo, bangkok, moscow, istanbul, london, paris, hanoi, madrid, ankara, berlin, casablanca, athens, budapest, rome, munich, bucharest, baku, vienna, stockholm, havana, minsk, warsaw, sofia, amsterdam, copenhagen, helsinki, prague, milan, brussels, belgrade, doha, tbilisi, yerevan, oslo, riga, krakow, thessaloniki, frankfurt, zagreb, vilnius, rotterdam, tallinn, lisbon, antwerp, skopje, bratislava, zurich, sarajevo, tirana, bonn, nicosia, armenia, strasbourg, ljubljana, maastricht, venice, geneva, basel, salzburg, lausanne, reykjavik, bern, luxembourg, greece, cannes, montenegro, petersburg, albania, malta, sweden, macedonia, davos, marathon
# Cluster 28: dhaka, lagos, kinshasa, luanda, khartoum, douala, nairobi, rangoon, abidjan, bamako, abuja, ibadan, algiers, sanaa, omdurman, mogadishu, lusaka, ouagadougou, yaounde, accra, antananarivo, harare, kano, blantyre, lubumbashi, brazzaville, tegucigalpa, kampala, conakry, kigali, dakar, muscat, mombasa, tripoli, bujumbura, maputo, bishkek, n'djamena, nouakchott, kisangani, ashgabat, niamey, monrovia, lilongwe, asmara, freetown, vientiane, bunia, bangui, dushanbe, kathmandu, libreville, kaduna, pretoria, cabinda, chisinau, cotonou, manama, jos, djibouti, tunis, rabat, nyala, bissau, juba, windhoek, arusha, banjul, chitungwiza, warri, maseru, malabo, goma, gaborone, toamasina, paramaribo, zanzibar, suva, calabar, podgorica, entebbe, mbabane, mali, liberia, togo, tome, apia, yamoussoukro, lome, moroni, angola
# Cluster 88: karachi, lahore, riyadh, baghdad, giza, jeddah, kabul, amman, tashkent, damascus, mecca, beirut, rawalpindi, aleppo, peshawar, mosul, shiraz, mandalay, srinagar, islamabad, quetta, kirkuk, homs, benghazi, kandahar, haifa, gaza, herat, samarkand, aden, farah, osh, ibb, bukhara, kunduz, jalalabad, babylon, netanya, beersheba, luxor, hebron, pristina, jabalya, rafah, sidon, khost, nablus, ghazni, jolo, seaside, chaman, tikrit, muzaffarabad, hadera, jaffna, baalbek, bethlehem, gardez, tulkarm, balad, afula, asadabad, eilat, qalat, gori, ramallah, timbuktu, dhahran, tskhinvali, wadi, jericho, sangin, tora, marib, bora, qana, garrison, grenade, heartland, qala
# Cluster 79: baoding, linyi, nanyang, zhoukou, ganzhou, heze, jining, fuyang, shangqiu, cangzhou, xingtai, zhumadian, hengyang, zunyi, shaoyang, shangrao, xinyang, liaocheng, huanggang, yulin, dezhou, nanchong, tai'an, changde, xiangyang, yichun, bozhou, ji'an, pingdingshan, mianyang, yuncheng, weinan, chenzhou, jiujiang, huaihua, yangzhou, taizhou, yiyang, lu'an, hengshui, anqing, zhangjiakou, chuzhou, linfen, xianyang, binzhou, wuhu, puyang, jiaozuo, deyang, shiyan, suining, hanzhong, zhenjiang, changzhi, leshan, xinzhou, huainan, meishan, chaoyang, longyan, handan, jinzhou, nanping, weifang, huai'an, zibo, ankang, luohe, dingxi, shaoxing, guangyuan, luoyang, jincheng, ma'anshan, pingliang, qingyang, sanmenxia, wuwei, siping, shuozhou, changshu, hebi, huzhou, baiyin, jinhua, chizhou, huangshan, yushu, yicheng, laiwu, yiwu, zhangye, guyuan, zhongwei, shouguang, taixing, taishan, kashgar, qingzhou, wuchang, tongchuan, danyang, xigaze, qamdo, qufu, turpan, anyang, nagqu, xicheng, hotan, dunhuang, altay, tarim, dongchuan, jingzhou, gannan, changji, jinzhong, chengde
# Cluster 52: lima, bogota, fortaleza, brasilia, guayaquil, medellin, cali, caracas, cordoba, manaus, curitiba, quito, montevideo, maracaibo, recife, barranquilla, belem, fes, managua, cartagena, bucaramanga, merida, cochabamba, cucuta, concepcion, beira, asuncion, manizales, buenaventura, callao, pasto, cuenca, antofagasta, paulista, palmas, sucre, valparaiso, ica, parana, americana, beni, granada, florencia, marbella, latina, altamira, cerro, chico, pisco, sur, libertad, fundacion, caldas, como, rivadavia, largo, asturias, olimpia, bolivar, isla, andes, colinas, aventura, guaira, minas, progreso, inca, avellaneda, alegre, pando, independencia, rioja, argos, cabildo, diamante, colonia, para, este, belo, bolivia, gran, antigua, pampas, peru, surinam, caracol, andalusia
# Cluster 72: tongshan, yuxi, shengli, yushan, xiping, zhongli, yucheng, jingling, kaiyuan, xishan, zhongxiang, xinyi, huilong, taihe, leping, xindi, qingping, hejian, puxi, qingnian, licheng, xichang, qianxi, jianshe, xinmin, xinxing, meilan, yuhuan, changping, wencheng, wancheng, longzhou, jiannan, fujin, longjiang, baisha, guangming, xunyang, jinshan, xiaoli, datang, longquan, dexing, shaowu, shenmu, dongning, longjing, yangmei, mogok, wapi, jinggang, liancheng, chaoshan, jinghai, dongsheng, xinjing, yima, zhaxi, cili, guagua, zhaozhou, fuyuan, jizhou, yuanlin, lianhe, wuling, yongqing, yilong, walbrzych, fanyang, weiyuan, dongping, linquan, julu, wangqing, changting, longhua, lugang, mingxing, wuyi, hukou, shiji, baharestan, mengla, puli, funing, fancheng, laiyuan, xinglong, keshan, huwei, qingquan, liuhe, longshan, guangping, berekum, jinxing, wuyang, xinfeng, chivilcoy, rodos, bonga, longmen, changling, xihu, xincheng, huaiyang, yongping, cuihua, fuxing, hekou, chauk, shanshan, vergina, salar, komoro, beigang, wujie, anyuan, vallehermoso, tulun, sanjiang, mtsensk, xiushui, yanqi, viru, yongjing, menen, tekes, taishi, beidou, xinyuan, fucheng, jiming, xingang, gukeng, wuyuan, dalin, mashan, perigueux, toucheng, hazar, kuli, longtan, haiyang, guanxi, qingshan, dongfeng, tianwei, ligang, utena, yanyan, budai, yuzhang, mandan, gonghe, daxin, gubbi, yangping, dagohoy, petrila, stabroek, xintian, taung, jiadong, lalibela, guoxing, puchov, jinji, linbian, nanbu, lugu, longji, serta, dacheng, sanyi, yuchi, dahe, alur, majia, wulong, kaoma, chenggong, sunne, vinings, shiwan, maqu, yakoma, hengshan, zao, gucheng, medog, svedala, fenglin, nanfang, zhengdong, glanmire, jixian, fuli, dahua, merville, gangadhar, tambura, recco, surak, iara, daping, yali, bifeng, dowa, gyangze, cantemir, fulin, muan
# Cluster 49: johannesburg, melbourne, sydney, brisbane, colombo, perth, auckland, adelaide, soweto, natal, durban, bulawayo, kingston, edinburgh, christchurch, canberra, victoria, bloemfontein, centurion, kimberley, wellington, hobart, geelong, townsville, cairns, darwin, bridgetown, dunedin, rugby, napier, twickenham, canterbury, bathurst, palmerston, collingwood, eden, jamaica, penrith, australia
# Cluster 76: chicago, miami, houston, dallas, philadelphia, toronto, atlanta, boston, phoenix, detroit, montreal, seattle, minneapolis, tampa, brooklyn, denver, vancouver, baltimore, portland, sacramento, austin, orlando, pittsburgh, indianapolis, manhattan, cincinnati, cleveland, columbus, charlotte, calgary, milwaukee, providence, jacksonville, nashville, edmonton, richmond, ottawa, memphis, hartford, louisville, buffalo, omaha, tulsa, rochester, dayton, columbia, albany, madison, oakland, syracuse, honolulu, anaheim, newark, anchorage, york, georgetown, metro, carolina, hampton, orleans, sparks, edison, auburn, florida, bay, virginia, usa, university, san, princeton, liberty, hudson, colorado, midway, oregon, cal, clemson, penn, stanford, indiana, california, college, center
# Cluster 18: santiago, salvador, santos, medina, rosario, trujillo, valenzuela, guadalupe, palma, toledo, rodriguez, carmen, garcia, zamora, salinas, leon, villanueva, ibarra, maldonado, trinidad, delgado, mendoza, ponce, bernal, morales, santana, carmona, lugo, colon, rubio, lopez, paredes, cardenas, robles, castro, rosales, oas, martinez, solano, rivera, guerra, alfonso, avila, alvarado, mora, ramon, moreno, jimenez, ortega, aguilar, flores, miranda, torres, rivas, molina, acevedo, cantu, abrego, luna, sosa, bautista, colombia, alba, espinosa, claudio, cruz, venezuela, perez, marco, sebastian, iglesias, cabrera, marin, ramos, allende, sanchez, gil, suarez, pastrana, heredia, valle, marcos, balaguer, toro, caldera, hugo, victor, lara, castillo, santa, rosa, roh, hidalgo, vazquez, gonzalez, gonzales, navarro, cisneros, zambrano, jacinto, rincon, padilla, margarita, cuellar, cortez, reyes, peralta, valdez
# Cluster 41: bijie, yancheng, maoming, jieyang, qujing, langfang, dazhou, yongzhou, zhaotong, suqian, jiangmen, yibin, meizhou, guigang, luzhou, zhaoqing, qiqihar, chifeng, qingyuan, loudi, zhuzhou, suihua, zaozhuang, neijiang, baicheng, hechi, qinzhou, bengbu, putian, tongren, wuzhou, rizhao, ningde, tongliao, shaoguan, heyuan, daqing, xiangtan, baotou, shanwei, chaozhou, sanming, yangjiang, jiamusi, lishui, zigong, huangshi, huludao, tieling, yunfu, anshun, yingkou, mudanjiang, lincang, laibin, puning, huaibei, chongzuo, hezhou, pingxiang, jixi, fushun, fuxin, heihe, jingdezhen, liaoyang, jiangyin, jiaxing, zhangjiajie, lianjiang, leizhou, rui'an, wenling, fuqing, wuzhong, yangquan, benxi, xintai, baishan, haicheng, huaiyin, yongcheng, shuangyashan, xinyu, rongcheng, liaoyuan, lianyuan, zhuji, yingtan, leiyang, xiantao, dongtai, dingzhou, yuyao, ezhou, hegang, fangchenggang, linhai, wafangdian, zaoyang, xingyi, xingcheng, wuchuan, zhuanghe, quzhou, jiaozhou, zhoushan, hai'an, laiyang, dehui, wu'an, gaoyou, dongyang, xiangxiang, korla, lichuan, wugang, shihezi, shishi, pinghu, sanhe, jieshou, guixi, jinghong, chuxiong, xinji, sihui, fu'an, lingyuan, lanxi, dangyang, wuhai, yanji, huanghua, fengcheng, fuding, heshan, hongjiang, beipiao, zhijiang, yuanping, yueqing, karamay, shahe, dunhua, xiaoyi, jiangshan, kuqa, huadian, yongji, danjiangkou, jinchang, hailin, fenyang, hejin, hancheng, yidu, jiayuguan, huayin, manzhouli, wuyishan, ormoc, hunchun, angarsk, gujiao, dongxing, golmud, kabankalan, tongjiang, linjiang, fukang, tacheng, zhengding, sagay, jinjiang, xiangcheng, kovrov, shizuishan, yaizu, isahaya, shuangcheng, silay, lucheng, oshu, ichinoseki, erdenet, catbalogan, balanga, talara, tomohon, shibukawa, oroquieta, lechang, itoman, suifenhe, kesennuma, canlaon, nichinan, gaocheng, donggang, yufu, sakaiminato, lufeng, calafat, shibam, konza
# Cluster 84: guadalajara, monterrey, tijuana, puebla, juarez, campinas, mexicali, morelia, aguascalientes, cancun, chihuahua, saltillo, hermosillo, culiacan, queretaro, albuquerque, durango, irapuato, reynosa, mazatlan, ensenada, veracruz, xalapa, celaya, villahermosa, cuernavaca, coatzacoalcos, oaxaca, pachuca, tampico, nogales, potosi, laredo, campeche, toluca, tapachula, guanajuato, manzanillo, cuauhtemoc, mexico, chetumal, guaymas, colima, orizaba, zacatecas, matamoros, tecate, cozumel, frontera, tupi, zihuatanejo, torreon, azul, palenque, teotihuacan, socorro, cananea, tuxpan, tulum, baja, lobos, tequila, alamogordo, reforma, cruces, tlaxcala, sonora, portales
# Cluster 71: alexandria, raleigh, charleston, knoxville, akron, harrisburg, springfield, augusta, kissimmee, winston-salem, chattanooga, greenville, pensacola, fayetteville, arlington, scranton, huntsville, greensboro, antioch, lansing, lexington, savannah, asheville, flint, shreveport, lubbock, lakeland, wilmington, tallahassee, gulfport, gainesville, tacoma, roanoke, brownsville, evansville, galveston, spartanburg, waco, ocala, murfreesboro, fredericksburg, leesburg, tuscaloosa, macon, topeka, houma, midland, lynchburg, duluth, clearwater, dearborn, charlottesville, joplin, decatur, anniston, jonesboro, hattiesburg, harrisonburg, blacksburg, sumter, reston, hendersonville, marietta, smyrna, bradenton, sarasota, biloxi, danville, manassas, covington, dekalb, wheeling, tupelo, leavenworth, gadsden, kennesaw, thomasville, paducah, selma, starkville, farragut, eustis, corinth, pascagoula, vicksburg, shenandoah, albemarle, monticello, natchez, shiloh, southside, tuskegee, pulaski
# Cluster 20: barcelona, tilburg, valencia, porto, sevilla, bordeaux, malaga, marseille, palermo, bilbao, zaragoza, murcia, dortmund, bremen, genoa, lyon, toulouse, lanus, piraeus, bologna, bochum, utrecht, alicante, bielefeld, salamanca, nantes, vitoria, bari, montpellier, catania, valladolid, vigo, monchengladbach, gijon, verona, eindhoven, elche, lille, groningen, rennes, banfield, messina, oviedo, padova, almeria, parma, brescia, getafe, breda, braga, toulon, nijmegen, amadora, albacete, santander, leverkusen, arnhem, perugia, cadiz, guimaraes, grenoble, livorno, cagliari, huelva, tarragona, leiria, ajax, wolfsburg, anderlecht, metz, perpignan, alkmaar, vicenza, caen, zilina, piacenza, kaiserslautern, cottbus, kallithea, lecce, compostela, cruzeiro, roosendaal, ajaccio, almelo, bayonne, genk, troyes, montauban, xanthi, doetinchem, lorient, siena, villareal, albi, empoli, waalwijk, bastia, martigues, stade, kerkrade, istres, clermont, valenciennes, castres, venlo, monaco, numancia, auxerre, lens, agen, heerenveen, hercules, unterhaching, biarritz, goias, volendam, palmeiras, sparta, velez, fortuna, tenerife, roda, roma, sociedad, wisla, levski, setubal, hansa, havre, esperance
# Cluster 77: izmir, mashhad, bursa, konya, mersin, adana, diyarbakir, tabriz, kayseri, samsun, balikesir, ahvaz, denizli, tabuk, eskisehir, erbil, erzurum, trabzon, malanje, zahedan, aksu, vinh, sanliurfa, kahramanmaras, malatya, elazig, asyut, manisa, hatay, gaziantep, sivas, alanya, kocaeli, pavlodar, dahuk, uige, gorgan, kashan, sakarya, kutahya, osmaniye, aydin, isparta, antalya, nonthaburi, aksaray, pecs, tarsus, ordu, tekirdag, sinop, gorontalo, kirikkale, bolu, sorsogon, edirne, tiaret, bodrum, tlemcen, karaman, siirt, manavgat, idlib, tokat, skikda, nador, bingol, ceyhan, erzincan, andong, tete, agri, kastamonu, bandundu, rize, igdir, yalova, zabol, atyrau, kusadasi, battambang, giresun, savannakhet, amasya, chabahar, yozgat, zonguldak, bamyan, marmaris, burdur, menderes, canakkale, pazardzhik, dobrich, mardin, essaouira, balkh, baghlan, najran, phitsanulok, yambol, kars, songkhla, champasak, kilis, rayong, saraburi, yala, kyustendil, kratie, hakkari, pursat, mugla, lampang, sirnak, tarma, bitlis, kardzhali, donsol, hajjah, tindouf, iznik, pattani, narathiwat, abadan, romblon, chachoengsao, kampot, chaiyaphum, byumba, ratchaburi, phatthalung, iyo, corum, smolyan, kalasin, uttaradit, chumphon, mukdahan, tunceli, lahij, krabi, salyan, chikuzen, batken, cankiri, kanchanaburi, enna, mimasaka, buzen, bulusan, cibitoke, chanthaburi, satun, phetchaburi, loei, phichit, phetchabun, kayanza, goroka, ghanzi, banaue, yasothon, bubanza, phayao, phrae, ranong, sukhothai, chuy, bulgan, kibungo, trat, phangnga, kirundo, muyinga, makamba, ruyigi, bururi, manica
# Cluster 17: kumasi, dnipro, wroclaw, lodz, poznan, gdansk, valletta, szczecin, brno, kaunas, hrodna, taraz, varna, plovdiv, debrecen, bor, bialystok, batna, cluj-napoca, katowice, ostrava, iasi, timisoara, gyor, szeged, brasov, limassol, craiova, kosice, sabadell, galati, lutsk, burgas, torun, oradea, plzen, zemun, zabrze, bytom, kragujevac, szombathely, miskolc, ruse, lleida, sibiu, pinsk, gyumri, pleven, lira, dharan, uzhhorod, sliven, shkoder, manzini, beja, rijeka, liberec, girona, siauliai, olomouc, klagenfurt, sopron, smederevo, tartu, pernik, maribor, osijek, monastir, pardubice, valjevo, volos, shumen, larnaca, suceava, daugavpils, elbasan, nitra, lod, arta, ramla, blagoevgrad, kumanovo, zadar, bitola, kladno, putrajaya, zrenjanin, szolnok, kraljevo, novi, kavala, ioannina, trnava, paphos, slatina, prilep, vaslui, trikala, vratsa, serres, mouscron, opava, zalaegerszeg, vranje, jelgava, giurgiu, komotini, chania, narva, pula, lankaran, teplice, hunedoara, poprad, tuba, vidin, razgrad, tiberias, jaro, kozani, silistra, dupnitsa, famagusta, veles, karditsa, zagora, zvolen, ohrid, celje, kranj, lovech, sandanski, jagodina, cieszyn, strumica, sopot, ventspils, rethymno, cheb, sakhnin, vinkovci, subotica, petrich, mioveni, winnenden, ob, srem, kikinda, esztergom, koper, velenje, pyrgos, birkirkara, kilkis, valmiera, dudelange, thebes, preveza, ptuj, edessa, florina, budva, viljandi, sliema, brod, kastoria, rakvere, sava, struga, buda, petrovaradin, sigulda, pomorie, pazar, urziceni, basseterre, ionia, cetinje, valga, gora, tizi, pella, jesenice, bohemia, macedon, trakai, echternach, vaduz, grevenmacher, ribnica, floriana, ilinden
# Cluster 30: busan, incheon, daegu, esfahan, dandong, haiphong, gwangju, daejeon, suwon, qom, shymkent, ulsan, goyang, barquisimeto, changwon, cheongju, bucheon, lubango, hamhung, nampo, latakia, wenchang, ansan, irbid, rustenburg, arak, pohang, pyeongtaek, jeju, kenitra, ismailia, agadir, paju, tetouan, gimpo, sinuiju, jeonju, asan, salalah, yanbu, wonju, yangsan, chuncheon, kunsan, yeosu, iksan, aswan, suncheon, sfax, constanta, iskenderun, kyongju, haeju, neyshabur, ashdod, bitung, mokpo, osan, gangneung, chungju, damietta, sejong, birjand, rajin, holon, kaesong, nis, ploiesti, masan, cuautitlan, riobamba, severodvinsk, seogwipo, hoeryong, sinpo, gwangyang, nakhodka, paranagua, rehovot, polokwane, fier, nouadhibou, gabes, tacurong, uitenhage, sangju, ginowan, tamanrasset, naju, gwadar, tartus, tagaytay, madaba, kashiwazaki, sokcho, sihanoukville, zinjibar, liepaja, tulcea, welkom, nago, kalamata, taebaek, abqaiq, dimona, marignane, mangalia, hengchun, munsan, khanabad, jinju, kourou, sighisoara, nazca, sines, natanz, itri, beibu, nelspruit
# Cluster 60: faisalabad, gujranwala, multan, rajshahi, khulna, narayanganj, bahawalpur, sargodha, mymensingh, sukkur, larkana, sylhet, chiniot, sirajganj, sanghar, kushtia, mardan, bogra, tangail, gujrat, karnal, pokhara, hangu, kasur, chakwal, comilla, panipat, rangpur, bhatinda, brahmanbaria, feni, nawabshah, sahiwal, hafizabad, jessore, biratnagar, okara, khanewal, thatta, turbat, dinajpur, jacobabad, parachinar, jhelum, pabna, narsingdi, sirsa, kohat, talas, haripur, jamalpur, ratnapura, muzaffargarh, ziarat, gojra, abbottabad, negombo, khuzdar, gweru, lalitpur, bongaigaon, patan, faridpur, kandy, nowshera, swabi, thimphu, satkhira, badin, ghotki, khushab, taungoo, charsadda, tinsukia, trincomalee, janakpur, mianwali, galle, bhakkar, bhola, batticaloa, kharian, taxila, habiganj, bhaktapur, pattoki, dambulla, manikganj, mansehra, matara, patuakhali, anuradhapura, gampaha, bannu, kathua, gaibandha, gorkha, karak, sherpur, sunamganj, zhob, kharan, badulla, matale, kalutara, pishin, udhampur, kokrajhar, barguna, shikarpur, chitral, kurunegala, baglung, siraha, parsa, nalbari, sibi, mandi, skardu, kulgam, kalat, kotli, phalia, murree, chandpur, kegalle, mehran, dera, dhemaji, ramechhap, doda, hambantota, rangamati, jumla, gilgit
# Cluster 29: taichung, kaohsiung, taipei, kowloon, tainan, macau, hsinchu, keelung, tsu, yao, hong, chiayi, formosa, bo, changhua, pingtung, yilan, nantou, chia, taitung, hualien, miaoli, ho, mao, kai, lian, gao, falun, wai, shu, ye, dao, kong, po, nan, tak, lai, shin, chang, kin, shing, hakka, panda
# Cluster 43: qincheng, cankaya, setagaya, ikeja, zhongba, nerima, umraniye, pendik, cocody, mamak, tondo, etimesgut, sincan, buca, kucukcekmece, kartal, bornova, ndjili, khayelitsha, cibinong, roodepoort, taubate, gungoren, itagui, fuchu, usak, sandton, sodo, mohammedia, kecskemet, catumbela, oeiras, basuo, pocheon, ekibastuz, odintsovo, iruma, pitesti, peristeri, payatas, marianao, zama, tabarre, panevezys, baraki, obninsk, petrzalka, hofu, jonkoping, kaposvar, pushkino, ilopango, bergama, rades, votkinsk, dongducheon, gavle, corumba, vanderbijlpark, kangan, arzew, glyfada, nikaia, midrand, baabda, pandacan, rafha, namsan, khewra, linkou, merignac, garhi, vsevolozhsk, sodertalje, russelsheim, tsuruga, kolonnawa, binga, korydallos, fujiidera, xiluodu, galatsi, trollhattan, gorlitz, krasnokamensk, jurmala, cojutepeque, mailiao, luwero, takahama, barendrecht, batajnica, kozlu, erlin, kashira, stepnogorsk, lucaya, surcin, vilvoorde, bakau, evere, halol, meftah, bouar, ahaus, kasumigaura, lambarene, kurchatov, kahrizak, moerdijk, magu, tarkwa, nyamata, kolin, kindi, kiryandongo, gongguan, mpwapwa, guyancourt, martorell, ludwigsfelde, brunssum, caracal, harbiye, neckarsulm, halemba, gressier, perama, saydnaya, marneuli, pavlovsk, etajima, sattahip, marcinelle, mihama, tervuren, bellavista, corail, azambuja, comalapa, tukwila, lucani, toktogul, colleferro, kubinka, visaginas, arese, balintawak, pokaran, motomachi, lgov, doura, meerssen, schwechat, murambi, paks, arcore, colbun, alcochete, wixom, pudu, naama, uusikaupunki, sayo, meco, kontiolahti, cernavoda, ayni, vredefort, loviisa, halawa, stafa, manoharpur, antas, vinto, nachikatsuura, kostolac, inawashiro, margraten, cadereyta, tarhunah, olen, cuers, osian, mutoko, heliopolis, kozloduy, snaresbrook, loran, dourdan, petrovka, gurun, rabta, winterville, naini, caslav, cordele, rokkasho, gadani, metsamor, humlebaek, fundeni, shchuchye, kadikoy, psychiko, kalaikunda, babadag, golbaf, spata, pithiviers, cheste, sanchi, montmelo, guntersville, pokrovka, dobanovci, danilovgrad, ignalina, golubovci, krsko, shamva, woomera, petrovec, lipkovo, chuquicamata
# Cluster 50: kyiv, almaty, novosibirsk, yekaterinburg, kharkiv, kazan, chelyabinsk, omsk, samara, rostov, ufa, krasnoyarsk, voronezh, perm, volgograd, krasnodar, donetsk, tyumen, saratov, lviv, makhachkala, izhevsk, barnaul, ulyanovsk, irkutsk, khabarovsk, yaroslavl, vladivostok, tomsk, orenburg, kemerovo, novokuznetsk, ryazan, astrakhan, penza, lipetsk, kirov, kaliningrad, sevastopol, mykolaiv, tula, kursk, stavropol, mariupol, tver, magnitogorsk, luhansk, sochi, ivanovo, bryansk, vinnytsia, arkhangelsk, chita, simferopol, belgorod, kaluga, smolensk, vologda, yakutsk, kurgan, vladikavkaz, tambov, chernihiv, poltava, kherson, kostroma, khmelnytskyi, novorossiysk, cherkasy, murmansk, sumy, chernivtsi, nalchik, zhytomyr, taganrog, rivne, ivano-frankivsk, ternopil, pskov, volgodonsk, batumi, odessa, kutaisi, khasavyurt, tiraspol, rustavi, domodedovo, nazran, magadan, azov, vorkuta, birobidzhan, beslan, vnukovo, sakha
# Cluster 67: birmingham, portsmouth, southampton, leeds, manchester, liverpool, leicester, newcastle, coventry, bolton, sunderland, derby, middlesbrough, tottenham, blackburn, wigan, wembley, wimbledon, watford, fulham, burnley, chelsea, boro, southgate, highbury, ferguson, aston, charlton, elland
# Cluster 82: stuttgart, hamburg, cologne, dusseldorf, leipzig, essen, dresden, hannover, nuremberg, duisburg, wuppertal, mannheim, karlsruhe, augsburg, graz, wiesbaden, gelsenkirchen, aachen, braunschweig, chemnitz, kiel, halle, magdeburg, krefeld, mainz, oberhausen, linz, rostock, kassel, potsdam, ludwigshafen, oldenburg, heidelberg, darmstadt, regensburg, paderborn, ingolstadt, innsbruck, ulm, heilbronn, pforzheim, erlangen, bremerhaven, koblenz, trier, jena, salzgitter, siegen, hildesheim, hanau, schwerin, ludwigsburg, giessen, gera, flensburg, zwickau, konstanz, bamberg, marburg, wilhelmshaven, landshut, bayreuth, brandenburg, aschaffenburg, celle, fulda, palatine, weimar, rosenheim, friedrichshafen, wels, greifswald, stralsund, baden-baden, schweinfurt, neustadt, passau, speyer, emden, goslar, freising, dachau, hof, filderstadt, gotha, eisenach, homburg, ansbach, coburg, freiberg, halberstadt, kehl, bautzen, merseburg, altenburg, bregenz, meissen, verden, baden, lindau, schleswig, burghausen, franconia, hanover, aue, westphalia, oberstdorf, erfurt
# Cluster 1: gulou, bekasi, depok, sumedang, cilacap, bhiwandi, tasikmalaya, namangan, serang, cimahi, touba, katlehong, cilegon, korba, sukabumi, karawang, jember, pekalongan, cirebon, sorong, tegal, setif, majene, annaba, kediri, mahajanga, purwokerto, singkawang, probolinggo, laayoune, apapa, cascais, ciputat, madiun, kankan, pasuruan, kindia, purwakarta, langsa, cianjur, bejaia, keningau, sampit, tema, bontang, bima, molo, chlef, mostaganem, eregli, tanay, silivri, bacau, veszprem, blitar, jijel, mojokerto, relizane, garut, magelang, juticalpa, indramayu, kadoma, banyuwangi, baripada, bintulu, kuningan, tawau, bukittinggi, witbank, kalmunai, lahan, chaguanas, sittwe, pyinmana, zahle, ciamis, sibolga, kwekwe, mandvi, leogane, maumere, karanganyar, pariaman, sumenep, dolisie, atambua, jepara, bafut, tuban, solok, sentani, ubud, bawku, pozarevac, bouira, banepa, reghaia, sodegaura, sawahlunto, lakhdaria, choshi, portimao, dompu, amalapuram, marondera, qalqilyah, harderwijk, ocosingo, boumerdes, oshakati, gabu, casiguran, merauke, lianga, aweil, kyrenia, partizansk, dellys, omaezaki, pisek, salou, palpa, zalingei, digboi, zemmouri, lamu, amstetten, gyegu, bafata, thenia, bronkhorstspruit, mundra, huanuni, belur, wenden, luganville, yumurtalik, karratha, maliana, baucau, sigli, torshavn, odder, ierapetra, rafina, lienz, vanimo, hobyo, yirol, manatuto, viqueque, lucea, liquica, tsavo, suai
# Cluster 45: mirzapur, tiruppur, tumkur, nellore, gulbarga, nagercoil, bhilwara, belgaum, chhatarpur, kurnool, davangere, bettiah, bellary, sonipat, rohtak, sikar, karur, sasaram, ahmadnagar, hosur, cuddapah, alwar, sambalpur, muzaffarpur, ratnagiri, kluang, shimoga, hapur, trichur, nizamabad, parbhani, karimnagar, dewas, jalna, satna, farrukhabad, ratlam, anantapur, jagdalpur, etawah, samastipur, begusarai, puducherry, myitkyina, katihar, tuticorin, ganganagar, bulandshahr, cannanore, raichur, vizianagaram, tanjore, khargone, panchkula, burhanpur, dindigul, ongole, deoghar, chhindwara, khandwa, bhiwani, bhind, khammam, mahbubnagar, batala, guna, nawada, jaunpur, shivpuri, unnao, sitapur, pilibhit, alleppey, cuddalore, gadag, tiruvannamalai, bidar, valsad, damoh, jind, madhubani, chittoor, sivakasi, bharuch, saharsa, vidisha, pathankot, kishangarh, nalgonda, hajipur, amreli, etah, kaithal, balasore, rewari, hazaribagh, mandsaur, villupuram, kumbakonam, mandya, raigarh, siwan, palwal, palghat, hanumangarh, arcot, hoshangabad, hardoi, dimapur, sivaganga, ghazipur, gurdaspur, khurda, chikmagalur, pudukkottai, adilabad, yavatmal, barnala, bijnor, balangir, bagalkot, osmanabad, sultanpur, shamli, wardha, sitamarhi, kishanganj, ballia, bundi, amaravati, buxar, tezpur, kapurthala, kohima, karwar, ponnani, sangrur, faridkot, shahdol, krishnagiri, mhow, ashoknagar, balrampur, bargarh, jamshoro, tikamgarh, araria, shajapur, yanam, malappuram, haveri, pattukkottai, rayagada, kodungallur, fatehabad, nabha, dhenkanal, gopalganj, guruvayur, jaisalmer, dharmapuri, washim, ramanathapuram, khagaria, rajgarh, nasirabad, karimganj, tiruvallur, tirur, pithoragarh, barwani, namakkal, kasaragod, goalpara, shahpur, tiruvalla, koraput, phaltan, tulsipur, sibsagar, baghpat, perambalur, dungarpur, dumka, nilambur, rameswaram, angul, medak, barpeta, jajpur, pratapgarh, golaghat, solan, nurpur, pathanamthitta, manali, kodaikanal, mokokchung, sirohi, hamirpur, almora, hangal, munnar, mahendragarh, kudat, ariyalur, gingee, deogarh, pauri, chengannur, tehri, sonepur, idukki, papanasam, nilgiri, nayagarh, khed, deoria, ganjam, chhapra, koppal, madhopur, muzaffarnagar, fatehgarh, rudraprayag, ramgarh, chamba, navsari
# Cluster 24: queens, riverside, bronx, bridgeport, hempstead, salem, concord, brookhaven, trenton, windsor, bergen, nassau, chesapeake, lafayette, norfolk, yonkers, huntington, waterbury, burlington, erie, danbury, newport, binghamton, bellevue, fairfield, stamford, dover, amherst, waldorf, chatham, woodbridge, riverview, norwalk, williamsburg, suffolk, middletown, plantation, bedford, germantown, avondale, pawtucket, camden, brunswick, passaic, rockville, grays, bethesda, brentwood, abington, towson, westchester, bloomfield, haverford, euclid, rye, westfield, woodstock, potomac, farmington, bridgewater, cove, hillsborough, annandale, woodlawn, delaware, marlborough, annapolis, montclair, cumberland, yorktown, freehold, wildwood, dartmouth, bethany, saratoga, milford, whitehall, jamestown, belmont, susquehanna, rockaway, edgewood, avon, greenbelt, fairfax, pelham, bloomingdale, waverly, raritan, kenmore, westerly, ashland, edgewater, roxbury, hopewell, smithfield, darien, manor, dorchester, meadowbrook, lackawanna, windham, pembroke, rockland, fairview, bethpage, adelphi, westbury, westport, sunnyside, parkway, longwood, bennington, newtown, riverdale, guilford, terrace, narragansett, iona, huron, nantucket, beacon, palmetto, amity, hillcrest, fulton, ridgefield, monmouth, lehigh, corning, fairmount, millstone, astoria, brandywine, bethel, oakwood, rensselaer, audubon, middlebury, schuylkill, lenox, montpelier
# Cluster 13: supaul, xinshi, purnea, bardoli, da'an, maungdaw, qardho, geita, sumbawanga, pathein, antsirabe, beykoz, kahama, baruta, kasulu, chuadanga, sambhal, menemen, amroha, tumpat, shrirampur, meiktila, hinthada, sullana, budaun, edremit, naogaon, nawabganj, bahawalnagar, pakpattan, mainpuri, luuq, kalol, tarime, gondia, puruliya, vihiga, lodhran, sahibganj, nandurbar, sehore, kulob, mityana, sheopur, natitingou, mubende, kheda, seoni, dhamtari, datia, songea, harnai, myingyan, wakiso, jamui, hetauda, lakshmipur, chingleput, panjgur, gumla, fazilka, surendranagar, shakargarh, tamana, kamuli, rajsamand, nalut, hasanpur, sangamner, sinnar, sheikhpura, itogon, ambanja, pirojpur, kasungu, lohardaga, moramanga, mafeteng, lunglei, myaungmya, sidhi, manjeri, tangkak, arwal, isfara, maubin, chatra, mpigi, godda, kawkareik, bhamo, manvi, garhwa, thoubal, yambio, sundargarh, batroun, manakara, raisen, murzuq, maroantsetra, pallisa, coyotepec, njombe, janjgir, jhabua, uttarkashi, ihosy, hailakandi, rusape, masasi, farafangana, mohnyin, umaria, kareli, bagrami, ibanda, changuinola, babati, ungheni, suzak, cahul, kayunga, trutnov, khunti, humansdorp, hajira, nkhotakota, sheohar, betong, guduru, mzimba, mananjary, latehar, saiha, tsaratanana, portalegre, pezinok, kyenjojo, chrudim, dindori, minbu, kiboga, soroca, taveta, anuppur, khowai, orhei, kyaukpyu, wittmund, narwar, hlohovec, pujehun, kanniyakumari, kamwenge, malacky, sironko, manikpur, sakri, shahkot, ntungamo, mwingi, androy, nymburk, bludenz, mendrisio, arbon, sirmaur, liestal, kaabong, drochia, leibnitz, chandauli, delemont, miesbach, deutschlandsberg, nakasongola, zofingen, ermenek, weiz, mistelbach, weinfelden, stollberg, rezina, amuru, imst, pitkyaranta, bonthe, opochka, monaragala, putao, judenburg, sursee, hochdorf, miltenberg, falam, voitsberg, arlesheim, bageshwar, zacharo, amuria, bududa, glodeni, tirschenreuth, nakaseke, nisporeni, leova, briceni, diekirch, librazhd, kalangala, samtse, ordino, mongar, kaberamaido, ainaro, trashigang, trongsa, tasiusaq, chikwawa, aileu, agago, nakapiripirit, tutong, sarpang
# Cluster 36: gaoping, wusong, mushin, seyhan, nenjiang, maringa, betsiboka, muar, itajai, chishui, kafue, cua, linhares, daule, tipitapa, dadu, atbara, batang, tumen, glan, balsas, labe, raba, miryang, manacapuru, babahoyo, paracatu, kitakami, sassandra, limay, pyapon, chateauguay, tura, xindian, jinsha, beypore, angat, pateros, ishim, ilog, irati, chikuma, ishikari, maun, limbang, stryi, hrazdan, tejen, burla, tubod, gediz, volkhov, pechora, agano, mokolo, whanganui, magra, ameca, patia, tiete, amargosa, sorel-tracy, kamenice, kamenka, kakhovka, praya, luga, hirakud, naryn, panuco, aravan, agno, casma, supe, axim, pedernales, nizao, dondon, abay, rakovski, traun, vrbas, jequitinhonha, lebu, moskva, nagold, zeya, manimala, manzanares, laja, tornio, aldan, saco, siran, mithi, hongshui, terek, babai, onega, zapote, loboc, zarumilla, nerang, chinde, baro, motru, anadyr, vakhsh, oria, mistassini, coomera, roding, meric, shilka, panj, mandu, enns, puyehue, chulym, waipio, achankovil, regen, tarra, neman, acari, vytegra, alamosa, arques, jinshui, covasna, sabie, zschopau, huasco, perkiomen, devnya, kratovo, barun, lachen, zambezi, umba, khatanga, vitim, mezen, nautla, urubamba, desaguadero, vipava, taedong
# Cluster 55: awka, vishakhapatnam, bamenda, kananga, ecatepec, guiping, onitsha, goiania, ulaanbaatar, hargeysa, maiduguri, nezahualcoyotl, matola, maceio, teresina, abeokuta, barinas, akure, ilorin, bhubaneshwar, khujand, osasco, orumiyeh, osogbo, uberlandia, bauchi, lokoja, kumul, aracaju, jalingo, cuiaba, bafoussam, tuxtla, uyo, andijon, valledupar, ibague, florianopolis, dispur, monteria, meknes, macapa, ile-ife, akhmim, buraydah, ado-ekiti, ulan-ude, tanta, sokoto, betim, zaria, cumana, jundiai, lobito, saurimo, yola, nnewi, petrolina, gusau, caruaru, petare, bauru, blumenau, umuahia, luena, gedaref, cabimas, semey, uberaba, uruapan, tepic, santarem, lafia, pucallpa, menongue, nukus, tehuacan, popayan, aizawl, sincelejo, sekondi, sumbe, petropolis, juliaca, palangkaraya, syktyvkar, dourados, araraquara, tarapoto, chimoio, nyiregyhaza, monclova, bayamo, owo, panabo, sunyani, parakou, barrancabermeja, huacho, helong, quelimane, guanare, chilpancingo, kairouan, salatiga, makurdi, kroonstad, tunja, teresopolis, zaranj, barreiras, lucapa, dutse, mzuzu, auchi, asaba, moundou, lichinga, botucatu, port-gentil, porto-novo, quibdo, thaton, harar, koforidua, bonao, cherkessk, navojoa, ligao, uruguaiana, kyzyl, catanduva, comitan, hezuo, daet, nsukka, franceville, seversk, yopal, texcoco, kanoya, ourinhos, francistown, boryeong, pavlohrad, zheleznogorsk, gangtok, alaminos, kontagora, ixmiquilpan, catarman, harran, glazov, kadugli, maracay, vanadzor, abomey, necochea, damaturu, potiskum, presov, nizwa, cabadbaran, polatsk, patzcuaro, lisala, caxito, latacunga, dschang, silao, lauderhill, alegrete, borongan, coari, badhan, tabatinga, aksum, gwacheon, magong, tandag, boryspil, viedma, itanagar, hastinapur, tulcan, moyobamba, mocoa, dongola, winneba, uriangato, korce, zabid, kangar, cobija, pyu, limbdi, otavalo, panaji, ataq, silves, oranjestad, ribeirao, sayram, hakha, lobatse, huejotzingo, maheshwar, manari, amarapura, coralville, geertruidenberg, artashat, ambohimanga, comrat, quepos, anzoategui, feyzabad, belmopan, calera, hilltown, baharu, kittur, tadjourah, cherrapunji, deblin, cojedes, makokou, avenal, tzintzuntzan, talakad, orchha, loikaw, martensville, magas, aibak, hsenwi, orlu, koror, chyhyryn, nawanagar, amapa, mtskheta, wabag, anouvong, abakaliki, yenagoa
# Cluster 83: karaj, kermanshah, kerman, rasht, hamadan, yazd, ardabil, sanandaj, qazvin, zanjan, savar, khorramabad, malard, dezful, babol, sabzevar, amol, pakdasht, najafabad, borujerd, varamin, saveh, bukan, semnan, maragheh, sirjan, malayer, mahabad, saqqez, rafsanjan, shahrud, quchan, marivan, andimeshk, marand, jiroft, salmas, behbahan, dorud, nazarabad, fasa, baneh, kashmar, shushtar, ahar, abhar, buin, behshahr, piranshahr, kuhdasht, shirvan, meybod, takestan, langarud, aligudarz, qorveh, shush, nahavand, bonab, ardakan, ramhormoz, naqadeh, khomeyn, sirvan, omidiyeh, zarand, neka, abyek, babolsar, esfarayen, damghan, borujen, taybad, tonekabon, javanrud, bijar, kahnuj, mahmudabad, tuyserkan, nowshahr, garmsar, damavand, azna, sardasht, bafq, azarshahr, sonqor, harsin, azadshahr, takab, mahallat, sarakhs, sarab, shadegan, delijan, gonabad, lordegan, tabas, fariman, khalkhal, rudsar, dargaz, kalaleh, sahneh, khodabandeh, baft, divandarreh, khvaf, dehloran, eyvan, farsan, minudasht, germi, ferdows, bardaskan, fuman, abarkuh, malekan, dehgolan, paveh, showt, bardsir, ramshir, ravansar, gotvand, deyr, ravar, shabestar, shazand, torqabeh, hashtrud, siahkal, hoveyzeh, kabudarahang, osku, nehbandan, ilam, jask, tafresh, boshruyeh, asara, manujan, anar, khamir, charam, amlash, razan, famenin, shandiz, sarayan, namin, rabor, landeh, rezvanshahr, bajestan, poldasht, basht, kuhbanan, aliabad, heris, ardal, bastak, sorkheh, marvast, mirjaveh, kaleybar, jolfa, komijan, ashtian, sarbisheh, babak, gharb
# Cluster 14: davao, arequipa, port-au-prince, antipolo, nampula, bacoor, villavicencio, bacolod, iloilo, chiclayo, salta, benguela, piura, cusco, malabon, neiva, huancayo, iquitos, butuan, iligan, palmira, cabuyao, corrientes, batangas, cotabato, camaguey, ha'il, tagum, resistencia, chimbote, machala, tacna, temuco, lucena, talisay, malolos, olongapo, tacloban, navotas, portoviejo, rancagua, neuquen, aguadilla, tulua, ayacucho, pagadian, talca, biskra, loja, arica, cajamarca, koronadal, tanauan, fianarantsoa, ouargla, malaybalay, digos, iquique, ambato, surigao, toliara, tuguegarao, kidapawan, osorno, catamarca, ilagan, calama, danao, esmeraldas, matanzas, talcahuano, badajoz, pleiku, calapan, cartago, dipolog, khorramshahr, antsiranana, arecibo, algeciras, huaraz, midsayap, tayabas, jaen, laoag, quezon, parral, masbate, ourense, bislig, malate, tumbes, bogo, mayaguez, maasin, dapitan, pontevedra, bulacan, baracoa, caguas, benidorm, guaynabo, ziguinchor, isabela, inhambane, taal, candon, trang, ushuaia, villarrica, bluefields, batac, huesca, vigan, mabini, alajuela, gracias, tuy, loreto, baler, antequera, caraga, ecija, estero, teruel, vitrolles, chachapoyas, jauja, paita, tocopilla, calamba, sarangani, comodoro, arauco, humacao, llanquihue, pichilemu, yungay, leones, marawi, anahuac, narino, bac, tandil
# Cluster 3: pimpri-chinchwad, haldwani, tenkasi, baramati, bhatpara, bhawana, brahmapur, khanapur, okene, ichalkaranji, arrah, malkajgiri, junagarh, pandharpur, saidpur, machilipatnam, nadiad, hospet, nandyal, karjat, baharampur, morbi, madanapalle, phillaur, chirala, neyveli, malkapur, adoni, tenali, khanpur, ambikapur, hindupur, jaranwala, nuzvid, narnaul, bhimavaram, dehri, mukerian, tuaran, wazirabad, sunam, nandgaon, dharmavaram, gudivada, phagwara, narasaraopet, kovilpatti, shegaon, rajpura, muktsar, jeypore, madhavaram, tiddim, amalner, vaniyambadi, tiruttani, pollachi, kavali, rasipuram, karad, bhawanipatna, bhalwal, mannargudi, gokak, dinga, tanuku, chintamani, tindivanam, srivilliputtur, dabra, gudur, mangalagiri, ratangarh, neyyattinkara, bapatla, badvel, valparai, suratgarh, palghar, dharapuram, siddipet, kanhangad, jagraon, palitana, sirsi, nawalgarh, gadwal, ranipet, nagari, nanjangud, panruti, vinukonda, tiptur, pasrur, mulbagal, palasa, macherla, kandukur, gudalur, bobbili, ropar, kharar, madhupur, polur, bhongir, khurai, puttur, kunnamkulam, sohna, venkatagiri, sihor, irinjalakuda, repalle, bhadrachalam, nohar, peddapuram, gooty, joshimath, hoskote, punalur, coonoor, kumta, melur, nandigama, ahmadpur, addanki, ramachandrapuram, ambasamudram, periyakulam, akbarpur, palladam, dildarnagar, nathdwara, rajgir, palampur, tiruchendur, ranipur, junnar, atmakur, kovvur, lalganj, cheyyar, attingal, sandur, phulbani, chunar, nakodar, musiri, pantnagar, chiplun, manamadurai, paithan, dapoli, kasba, chavakkad, madikeri, kartarpur, chanderi, kangayam, tuljapur, sholinghur, dharampur, shahpura, magadi, ibrahimpatnam, pattambi, rajpur, kotagiri, amarpur, penukonda, mavelikara, renigunta, krishnapuram, karkala, namrup, velur, ponneri, annur, lalgudi, alangulam, rampura, mandawa, tekari, sonari, shurugwi, ondangwa, perundurai, adampur, kuppam, bhanpura, padmanabhapuram, doaba, sriperumbudur, agropoli, kudal, gannavaram, chennimalai, chandragiri, pulicat, lonar, depalpur, goraya, katpadi, otjiwarongo, narsapur, sirpur, kangazha, bhawanipur, payyannur, bendorf, sikandra, majra, jalalpur, gokarna, attur, udayagiri, damdama, rajapur, chittur, cumbum, gangapur, lakkundi, alampur, madhuban, pudur, halwara, barhi, alangudi, polavaram, panchgani, kalanaur, bahadurpur, mahabaleshwar, murud, eraniel, yercaud, jagdishpur, bhattiprolu, jagannathpur, ghanpur, alipur, perur, daulatpur, nanguneri, kottur, manpur, birdsville
# Cluster 81: masvingo, mwanza, chengguan, mbale, nakuru, mbeya, ndola, kitwe, eldoret, ajdabiya, kisumu, magway, bago, gombe, taunggyi, mawlamyine, mutare, tabora, chilas, monywa, morogoro, mpanda, mazabuka, iringa, segamat, mbarara, kenema, mongu, kasama, singida, garissa, mukono, gulu, lashio, kiambu, chingola, bukoba, moshi, paghman, kigoma, pyay, koidu, kilifi, hoima, malindi, butwal, luanshya, kabwe, kasese, machakos, nkayi, kisii, masindi, shinyanga, masaka, musoma, tanga, thika, sisophon, nyeri, chipata, mtwara, kakamega, raub, solwezi, chililabombwe, wajir, shwebo, chirundu, afgooye, kengtung, jinja, sagaing, limbe, apac, chegutu, narok, embu, busia, nawa, bhairahawa, rundu, kitale, arua, karonga, soroti, kakuma, bungoma, iganga, kabale, yendi, choma, tachilek, mangochi, yumbe, bindura, lawas, isiolo, dodoma, puttalam, nimule, kitgum, bushenyi, meru, hwange, tamu, iten, tororo, beitbridge, lindi, nebbi, magburaka, chiredzi, kambia, koboko, rukungiri, adjumani, bugiri, bagamoyo, chipinge, dedza, mandera, kailahun, kericho, kitui, pakwach, mpika, mchinji, nsanje, nyanza, moyale, kajiado, kariba, kotido, bundibugyo, tongzhou, mulanje, malaba, kawambwa, mbala, sesheke, senec, tsumeb, mumbwa, dharmsala, dadeldhura, kisoro, marsabit, lodwar, ngara, moroto, aranyaprathet, mwinilunga, kanungu, naivasha, gwanda, kapchorwa, karagwe, moyamba, ngorongoro, nakonde, bakwa, kwale, kanchanpur, katakwi, kasane, kishtwar, rakai, kalabo, kibale, thyolo, gizo, katwe, lupane, pader, nyamira, siaya, migori
# Cluster 44: yopougon, guarulhos, iguacu, sorocaba, marka, londrina, niteroi, piracicaba, sintra, olinda, cascavel, canoas, pelotas, crato, imperatriz, limeira, juazeiro, alvorada, matosinhos, lajes, caxias, poblacion, coro, pantanal, salto, votorantim, resende, barcelos, bage, sorriso, lagarto, bumba, patos, aracruz, viseu, leme, paraiso, aveiro, copacabana, reconquista, mindelo, farroupilha, buenavista, formiga, estancia, faro, penedo, praia, salgueiro, registro, pirapora, amarante, esquipulas, pombal, palmares, granja, peine, montijo, leopoldina, barra, pontal, nicoya, pedreira, playas, diamantina, obra, uniao, lapa, ksar, guarda, copan, pinhal, abrantes, penalva, atalaia, bonito, aguilas, sile, aparecida, maspalomas, santuario, castelo, centenario, brejo, palmeira, crema, penha, guararapes, estrela, capela, bandeirantes, fomento, floresta, anchieta, tacuba, quiapo, buriti, funchal, cachoeira, campina, prata, triunfo, jardim, cangas, jumilla, nacimiento, batalha, pacasmayo, vignola, maracana, piranhas, condado, reserva, laranjeiras, seveso, planalto, lagoa, pedra, areia, cedro, chapala, varadero, mirador, campestre, binondo, araripe, ipanema, barro, paranapanema, duero, retiro, madalena, viradouro, sainte-catherine, carmo, salitre, medicina, tocantins, conchas, zombo, salida, ipiranga, pilas, pacaembu, barah, choro, calheta, feira, quilombo, keila, cameri, vargem, saudade, catarina, rotonda, mirante, foz, busca, grado, peixe, pieta, igreja
# ...
# Cluster 11: finglas, urayasu, soke, wythenshawe, wallasey, hurlingham, bebington, clondalkin, strood, laindon, borehamwood, carrollwood, pandan, walkden, wickford, huyton, bexleyheath, ecclesfield, harpenden, bulwell, crofton, hanwell, bushey, bearsden, burntwood, rosemount, bournville, upminster, kingswinford, cambre, farnley, rickmansworth, caversham, gosforth, rathfarnham, harborne, erdington, shoeburyness, acomb, silverdale, caterham, normanton, failsworth, kirkstall, maghull, seaham, bispham, biddulph, davyhulme, ballyfermot, dukinfield, ecclesall, frimley, molesey, gentilly, monkseaton, southbourne, horsforth, fairwood, kingsland, hadleigh, pinecrest, fulwood, stillorgan, barrhead, woodcrest, braunstone, fazakerley, windlesham, bredbury, banstead, cleckheaton, birstall, basford, riversdale, addlestone, seacombe, perivale, broxbourne, bidston, northenden, chellaston, totteridge, winkfield, kenley, wyke, baguley, lowton, moston, chelsfield, kidbrooke, somerton, seacroft, kearsley, ashtead, streetly, rustington, kidlington, childwall, heswall, amblecote, hamworthy, yiewsley, woolton, leagrave, chilwell, sanderstead, ainsdale, brownhills, chigwell, spondon, coseley, giffnock, olton, tring, sedgley, kotla, eckington, trentham, sunninghill, brislington, culcheth, cantley, haydock, greetland, oxted, chorleywood, stanwell, linslade, aylestone, dorridge, evington, timperley, ponteland, binbrook, flixton, parkstone, ormesby, killiney, ryhope, ickenham, broadstone, penetanguishene, radlett, chapeltown, euxton, birchington, aldenham, tottington, dodworth, felpham, glenfield, yarm, killamarsh, horsell, towcester, bowdon, tilehurst, littleport, portlethen, ifield, sompting, worplesdon, hughenden, oatlands
# Cluster 46: youngstown, bremerton, clarksville, lorain, hagerstown, nampa, gastonia, marysville, elkhart, saginaw, hillsboro, kingsport, muncie, springdale, minden, morgantown, elizabethtown, lehi, pittsburg, owensboro, pocatello, sheboygan, dothan, centreville, altoona, janesville, dubuque, corvallis, parkersburg, richland, kokomo, bentonville, elyria, florissant, mishawaka, jeffersonville, stillwater, titusville, minot, ocoee, salina, gallatin, riverton, mankato, wilkes-barre, westerville, rexburg, mechanicsville, lewiston, bartlesville, muskogee, richfield, norristown, midvale, cookeville, goshen, manitowoc, mcminnville, goldsboro, clearfield, massillon, maryville, opelika, hopkinsville, westville, morrisville, bluffton, russellville, statesville, monroeville, frankfort, clarksburg, williamsport, swatara, marshalltown, wasco, wilsonville, bessemer, ottumwa, elkridge, barberton, sandusky, wyandotte, ardmore, zanesville, centerville, emporia, shelbyville, muscatine, watauga, pottstown, christiansburg, fairhope, abbeville, warrenton, biddeford, waynesboro, ruston, lorton, chillicothe, chambersburg, sedalia, palatka, tullahoma, elko, piqua, painesville, rolla, kinston, madisonville, sweetwater, warrensburg, ferndale, lumberton, ellensburg, weirton, ansonia, phoenixville, altus, martinsburg, berea, cullman, johnstown, steubenville, logansport, mcalester, ashtabula, sevierville, doylestown, natchitoches, willimantic, anacortes, kirksville, morganton, wailuku, tahlequah, crawfordsville, dyersburg, indianola, elkton, opelousas, waterville, thibodaux, scottsboro, bemidji, yankton, vandalia, greensburg, clarksdale, roseau, clarkston, moultrie, reidsville, elizabethton, pineville, circleville, maumee, coldwater, bardstown, pottsville, orangeburg, pomfret, meadville, fostoria, bloomsburg, eufaula, neosho, baraboo, escanaba, lewisburg, effingham, crossville, lawrenceburg, hartsville, platteville, loyalsock, campbellsville, okmulgee, batesville, marinette, coshocton, bogalusa, nanticoke, ironton, vermilion, wabash, smithville, arkadelphia, waynesville, elkhorn, alpena, atoka, uniontown, wapakoneta, keokuk, greencastle, thomaston, bluefield, bladensburg, mechanicsburg, wasilla, conshohocken, harrodsburg, lapeer, booneville, maysville, glenwood, perryville, lewistown, philipsburg
# Cluster 63: afyonkarahisar, bayat, nazilli, erdemli, milas, navoiy, m'sila, kozan, serik, kahta, guelma, silifke, qiaotou, khenchela, jalal-abad, loznica, haskovo, bilecik, kumluca, merzifon, anamur, mobarakeh, kozluk, korkuteli, zhushan, gabrovo, mudhol, alytus, finike, suluova, farim, haymana, prievidza, dikili, germencik, vahdat, slobozia, dowlatabad, bayburt, quba, prokuplje, besni, goygol, prijepolje, negotin, shamsabad, tutin, levice, sadabad, zaqatala, sabirabad, zgharta, vlasotince, ivanjica, jonava, aleksandrovac, kuyucak, demre, artvin, jafarabad, parner, hopa, gerede, svilajnac, ardahan, karnobat, sevlievo, nikolskoye, topola, hamidiyeh, lebane, artemida, beroun, mohammadabad, kladovo, arhavi, sultanhisar, agsu, agstafa, bilasuvar, brezno, yusufeli, arilje, snina, tufanbeyli, karacasu, kushk, trstenik, astara, qusar, feke, kurdamir, veys, shal, galanta, amasra, malvik, mionica, svrljig, sjenica, tovuz, akseki, khomam, kalecik, sason, yenipazar, lamphun, sangar, ancuabe, qarah, sabinov, tryavna, lenvik, chamestan, asalem, tolna, broomall, lubawa, ordubad, kemin, meymand, stropkov, mengen, miastko, gadabay, kenar, lohara, camenca, sredets, saidabad, rayon, loenen, zardab, golubac, paide, grosuplje, goranboy, lerik, kolonia, zagorje, rapla, trebnje, agdam, balakan, qubadli, bosilegrad, boljevac, priboj, bojnik, qabala
# Cluster 65: kotri, lubeck, saarbrucken, epe, osnabruck, solingen, daltonganj, neuss, mogaung, wurzburg, gottingen, reutlingen, remscheid, recklinghausen, kasserine, moers, gutersloh, esslingen, tubingen, iserlohn, ratingen, velbert, norderstedt, delmenhorst, rheine, hoofddorp, detmold, arnsberg, bocholt, kempten, lippstadt, aalen, minusinsk, herford, kerpen, neuwied, dormagen, villach, sindelfingen, plauen, grevenbroich, neubrandenburg, offenburg, wesel, unna, tikhvin, hameln, waiblingen, langenhagen, nordhorn, wetzlar, kleve, harrismith, gummersbach, ravensburg, rastatt, heidenheim, cuxhaven, gronau, leonberg, straubing, frankenthal, bornheim, hennef, oranienburg, neunkirchen, anandpur, kaufbeuren, weinheim, pinneberg, erkelenz, wismar, gifhorn, borken, heinsberg, bensheim, wunstorf, eberswalde, nordhausen, schwabach, buxtehude, neumarkt, lemgo, ettlingen, mettmann, ilmenau, stendal, pirna, weissenfels, papenburg, bitterfeld, warendorf, tuttlingen, beckum, cloppenburg, coesfeld, sinsheim, emsdetten, winsen, meppen, deggendorf, steinfurt, balingen, saarlouis, ahrensburg, geldern, biberach, uelzen, vechta, forchheim, naumburg, bernburg, itzehoe, wernigerode, neuruppin, hoyerswerda, werl, einbeck, neuburg, andernach, rendsburg, northeim, saalfeld, riesa, emmendingen, geilenkirchen, grimma, arnstadt, griesheim, teltow, butzbach, klosterneuburg, wiesloch, heppenheim, pfaffenhofen, hennigsdorf, aschersleben, achern, lichtenburg, nordenham, kotal, kulmbach, helmstedt, ellwangen, idstein, rottweil, sangerhausen, wolfsberg, plettenberg, zittau, rudolstadt, meiningen, rathenow, herzogenaurach, varel, calw, grootfontein, starnberg, korbach, gelnhausen, salzwedel, dillenburg, senftenberg, quedlinburg, apolda, kitzingen, laupheim, stadthagen, metzingen, donaueschingen, frauenfeld, eschborn, schwetzingen, sonthofen, kreuzlingen, xanten, seligenstadt, zerbst, osterode, sondershausen, traunstein, forbach, herborn, luckenwalde, greiz, neustrelitz, holzminden, dillingen, moosburg, torgau, wittlich, oschersleben, eschwege, hechingen, alzey, blankenburg, kufstein, prenzlau, kalach, sigmaringen, parchim, diepholz, swellendam, remagen, babenhausen, schwalbach, eutin, kelheim, kamenz, kronach, bitburg, marienberg, guben, sulzbach, alsfeld, eilenburg, walldorf, dieburg, fritzlar, witzenhausen, jever, ratzeburg, ottweiler, abensberg, eberbach, neubiberg, mittweida, oschatz, schneeberg, erbach, melsungen, philippsburg, ettenheim, rheinfelden, weilburg, manching, gmunden, hadamar, schleiden, winterberg, steinheim, anklam, ludwigslust, wolgast, lauenburg, hildburghausen, altdorf, fallersleben, haigerloch, neuhof, hammelburg, lichtenau, nauheim, katra, lenzburg, friedeburg, demmin, querfurt, payerne, laubach, dassel, ilsenburg, wunsiedel, biblis, kirchberg, zwiesel, tuscumbia, schleiz, kilchberg, ballenstedt, bremgarten
# Cluster 89: fort-de-france, leganes, saint-etienne, bayamon, villeurbanne, boulogne-billancourt, montreuil, tourcoing, caseros, creteil, aubervilliers, colombes, manresa, rueil-malmaison, majadahonda, saint-nazaire, drancy, issy-les-moulineaux, cergy, levallois-perret, pessac, venissieux, ivry-sur-seine, ferrol, pantin, aranjuez, neuilly-sur-seine, sarcelles, frejus, hyeres, bobigny, clamart, chelles, evry, saint-ouen, saint-quentin, corbeil-essonnes, cagnes-sur-mer, sevran, massy, gennevilliers, suresnes, saint-priest, montrouge, saint-malo, evreux, rivoli, meudon, noisy-le-sec, cavaillon, saint-eustache, talence, alfortville, saint-brieuc, bagneux, puteaux, melun, thionville, bourg-en-bresse, anglet, boulogne-sur-mer, saint-germain-en-laye, gagny, poissy, bagnolet, villepinte, thonon-les-bains, esch-sur-alzette, creil, chatelet, haguenau, palaiseau, schiltigheim, trappes, binche, nogent-sur-marne, romainville, saint-georges, epinal, aix-les-bains, pontoise, thiais, dreux, carpentras, mont-de-marsan, cachan, lievin, saint-cloud, chatou, fresnes, nivelles, vanves, montfermeil, grigny, blagnac, bergerac, lunel, gonesse, vierzon, libourne, saint-nicolas, frontignan, maisons-laffitte, saint-dizier, sevres, fleurus, torcy, saint-lazare, chaumont, arcueil, hazebrouck, varennes, argenta, elvas, denain, sceaux, beaune, mougins, vence, moulins, royan, louviers, garches, marmande, montbrison, orsay, beaucaire, senlis, longwy, vesoul, morlaix, bailleul, dinan, bar-le-duc, saint-jean-de-luz, flers, saint-gilles, shepherdsville, lachute, thouars, moissac, enghien, gien, gex, noyon, amboise, castelnaudary, marly, provins, gisors, saverne, arcachon, gravelines, dinard, saint-sauveur, bernay, belley, rivesaltes, bougival, stans, saint-pierre
# Cluster 37: jinshi, moratuwa, batley, feltham, smethwick, kirkby, hoddesdon, urmston, beeston, billingham, brighouse, prestwich, pontypridd, bicester, kendal, darlaston, longton, keswick, farnworth, longbridge, hindley, penistone, rugeley, rishton, whitefield, penwortham, rawtenstall, wednesfield, pudsey, yeadon, ensley, horley, sandbach, yate, royton, dronfield, wallington, celbridge, rothwell, halewood, killingworth, horwich, irlam, garforth, mirfield, kempston, staveley, heckmondwike, madeley, ramsbottom, whittlesey, cottingham, haslingden, keynsham, northbridge, tyldesley, chertsey, matlock, todmorden, stapleford, baildon, neston, blaydon, netherton, hessle, ilkley, romsey, thornbury, littleborough, otley, middlewich, rossington, hemsworth, pendlebury, milnrow, lymm, hersham, wetherby, ulverston, bolsover, burtonwood, crayford, prescot, chatteris, cudworth, rainhill, desborough, cheam, pocklington, horbury, baldock, kippax, newburn, emsworth, middlesborough, lutterworth, frodsham, tiptree, barwell, newstead, penkridge, northam
# Cluster 27: gandhidham, palanpur, chigasaki, isesaki, chakradharpur, joetsu, kokubunji, nagda, guntakal, bottrop, sandvika, orsha, itarsi, arden-arcade, longchuan, lelystad, manmad, viersen, fukuchiyama, troisdorf, thakhek, kotlas, neu-ulm, euskirchen, maisons-alfort, villejuif, kollegal, raxaul, hattingen, sultanganj, salekhard, elmshorn, singen, herzogenrath, schwerte, brive-la-gaillarde, bruchsal, rodgau, tamagawa, memmingen, seregno, lehrte, mantes-la-jolie, zevenaar, bietigheim-bissingen, himi, nijkerk, shoranur, siegburg, kirkkonummi, pirmasens, hofheim, schorndorf, empalme, saronno, maibara, ibara, backnang, gomoh, formia, uster, crailsheim, isumi, kerava, dietzenbach, viernheim, meppel, kornwestheim, radebeul, herrenberg, yenice, stadskanaal, kuroishi, lumding, walsrode, treviglio, bretten, schwandorf, winterswijk, schwelm, overath, strausberg, rheinbach, fidenza, dietikon, pantar, chivasso, friedrichsdorf, brilon, olpe, meckenheim, delfzijl, wetzikon, freudenstadt, husum, sonneberg, mosbach, horgen, weilheim, carouge, sambhar, eppingen, glauchau, soltau, lindlar, iisalmi, zossen, bologoye, germersheim, wettingen, sarreguemines, schifferstadt, dingolfing, coswig, lannion, lichtenfels, haiger, dudinka, kemi, annaberg-buchholz, nauen, wolfratshausen, weesp, virovitica, iiyama, seesen, mont-saint-hilaire, jasidih, renningen, thalwil, olten, ismaning, freilassing, monthey, domodossola, nidda, kelsterbach, gunzenhausen, marktredwitz, frederikssund, thale, wittenberge, keetmanshoop, holzkirchen, pocking, ascheberg, mindelheim, boppard, einsiedeln, mering, schriesheim, usingen, niedernhausen, gryazovets, selb, plochingen, montabaur, askim, rheydt, feucht, luino, neuenkirchen, bebra, buchloe, cosham, pegnitz, versoix, plattling, treuchtlingen, spiez, hersbruck, schongau, buchs, graben-neudorf, hagenow, ebersberg, zeuthen, nikel, hinwil, romanshorn, brugg, bischofswerda, filipstad, lemington, betzdorf, tutzing, fiuggi, schotten, lomazzo, kiato, pasewalk, pechory, altenbeken, sassnitz, yatton, katsuyama, iseo, landquart, tirano, brevik, otavi, komatipoort, narrogin, dobrova, meekatharra, quilpie
# Cluster 48: nashua, medford, leominster, brockton, moca, somerville, framingham, lakeville, haverhill, malden, waltham, brookline, meriden, braintree, chicopee, andover, barnstable, attleboro, pittsfield, woonsocket, coram, billerica, fitchburg, brookfield, newbury, woburn, holyoke, natick, dracut, naugatuck, tewksbury, stoughton, stockbridge, rehoboth, agawam, saugus, danvers, williston, merrimack, marshfield, dedham, watertown, westford, middleborough, hingham, wareham, stoneham, westborough, marblehead, deerfield, scituate, hopkinton, foxborough, newburyport, southbridge, amesbury, auburndale, easthampton, duxbury, fairhaven, longmeadow, northborough, seekonk, belchertown, mashpee, swampscott, raynham, holliston, williamstown, wilbraham, eastham, millbury, wayland, southwick, lynnfield, medfield, wrentham, brattleboro, pepperell, norwell, groton, southborough, acushnet, attleborough, winchendon, rockport, sturbridge, plainville, weare, mendon, millis
# Cluster 51: abakan, copiapo, logrono, nimes, besancon, forli, kiffa, gerona, beziers, tambacounda, seraing, ponferrada, chambery, alcoy, cholet, tarbes, chateauroux, angouleme, vasto, montelimar, compiegne, waregem, annemasse, maddaloni, chur, roanne, almendralejo, montlucon, termoli, camaiore, valdepenas, ostuni, agde, etampes, miramas, calpe, aurillac, montbeliard, alencon, rodez, dalmine, challans, epernay, savigliano, borgomanero, wasquehal, givors, longjumeau, cahors, vitre, guadix, fecamp, pornic, pontarlier, hendaye, luneville, brignoles, martigny, cluses, sallanches, annonay, pamiers, gaillac, tidjikja, tarascon, lyss, montargis, issoire, auray, castelsarrasin, marostica, wanze, autun, lamballe, varazze, obernai, encamp, issoudun, lavaur, vire, orthez, briancon, bischofshofen, mazamet, valdobbiadene, figeac, racconigi, foix, sabinanigo, ouistreham, joigny, embrun, skovorodino

# %% [markdown]
# This code calculates the maximum pairwise distance between the centroids of a given set of clusters. Each cluster is represented by a list of words, and their corresponding embeddings are used to compute the centroid. The process is as follows:
#
# 1. **Calculate Centroids:** For each cluster, the embeddings of the words in the cluster are retrieved and used to calculate the centroid by taking the mean of the embeddings along each dimension.
#
# 2. **Compute Pairwise Distances:** The Euclidean distances between all pairs of centroids are computed to form a matrix of distances.
#
# 3. **Find Maximum Distance:** The maximum distance in the matrix is identified, representing the largest pairwise distance between any two cluster centroids.
#
# 4. **Print Result:** The maximum pairwise distance is printed as the sensitivity measure (`sensitivity_inter`).

# %%
# Calculate centroids of each cluster
centroids = {}
for label, words in clusters.items():
    cluster_vectors = [city_embeddings[word] for word in words]
    centroids[label] = np.mean(cluster_vectors, axis=0)

# Compute pairwise distances between centroids
centroid_labels = list(centroids.keys())
centroid_vectors = [centroids[label] for label in centroid_labels]
distances = euclidean_distances(centroid_vectors, centroid_vectors)

# Find the maximum distance
sensitivity_inter = np.max(distances)

print(f"The maximum pairwise distance between cluster centroids is: {sensitivity_inter}")
# Out:
# The maximum pairwise distance between cluster centroids is: 1.0172011256229572

# %% [markdown]
# In this modified code, instead of computing the distances between centroids,
# we use the cdist function from `scipy.spatial.distance` to compute all pairwise distances between the members of two different clusters.
# We then take the maximum of these distances as the distance between the two clusters.
# The maximum of all these cluster-to-cluster distances is then used as sensitivity_inter.

# %%
# Calculate centroids of each cluster
centroids = {}
for label, words in clusters.items():
    cluster_vectors = [city_embeddings[word] for word in words]
    centroids[label] = np.mean(cluster_vectors, axis=0)

# Compute maximum pairwise distances between clusters
max_distances = np.zeros((len(centroids), len(centroids)))

for i, label1 in enumerate(centroids.keys()):
    for j, label2 in enumerate(centroids.keys()):
        if i != j:
            cluster_vectors_1 = [city_embeddings[word] for word in clusters[label1]]
            cluster_vectors_2 = [city_embeddings[word] for word in clusters[label2]]
            distances = cdist(cluster_vectors_1, cluster_vectors_2, metric='euclidean')
            max_distances[i, j] = np.max(distances)

# Find the maximum distance
sensitivity_inter = np.max(max_distances)

print(f"The maximum pairwise distance between any two clusters is: {sensitivity_inter}")
# Out:
# The maximum pairwise distance between any two clusters is: 1.7514913100634877

# %% [markdown]
# This code defines a function `compute_largest_intracluster_distance` that calculates the largest Euclidean distance between any two points within each cluster of a given set of clusters. The function iterates over each cluster, retrieves the embeddings for the words in the cluster, computes the pairwise distances between all points in the cluster using the `pdist` function with the Euclidean metric, and then finds the maximum distance. This maximum distance represents the largest intracluster distance for that cluster. The results are stored in a dictionary `sensitivity_intra` where the keys are the cluster labels and the values are the largest intracluster distances. The function returns this dictionary, and the results are printed for each cluster.

# %%
from scipy.spatial.distance import pdist, squareform

def compute_largest_intracluster_distance(clusters, embeddings):
    sensitivity_intra = {}
    for label, words in clusters.items():
        # Get the embeddings for the words in the cluster
        cluster_embeddings = [embeddings[word] for word in words]
        
        # Compute the pairwise distances within the cluster
        if len(cluster_embeddings) > 1:
            distances = pdist(cluster_embeddings, metric='euclidean')
            # Find the maximum distance
            max_distance = max(distances)
        else:
            # If the cluster has only one element, set the max distance to 0
            max_distance = 0
        
        # Store the result in the dictionary
        sensitivity_intra[label] = max_distance
    
    return sensitivity_intra

# Compute the largest intracluster distance for each cluster
sensitivity_intra = compute_largest_intracluster_distance(clusters, normalized_embeddings)

# Print the results
for label, max_distance in sensitivity_intra.items():
    print(f"Cluster {label}: Largest intracluster distance = {max_distance}")
# Out:
# Cluster 69: Largest intracluster distance = 1.4601717415369153
# Cluster 7: Largest intracluster distance = 1.423194090980196
# Cluster 90: Largest intracluster distance = 1.3988365044139837
# Cluster 68: Largest intracluster distance = 1.3043284470413257
# Cluster 97: Largest intracluster distance = 1.525722252915953
# Cluster 25: Largest intracluster distance = 1.4461332423759907
# Cluster 28: Largest intracluster distance = 1.440031300192401
# Cluster 88: Largest intracluster distance = 1.4779192448068106
# Cluster 79: Largest intracluster distance = 1.4177800818537605
# Cluster 52: Largest intracluster distance = 1.444309965051001
# Cluster 72: Largest intracluster distance = 1.4815757396934381
# Cluster 49: Largest intracluster distance = 1.4299047080936989
# Cluster 76: Largest intracluster distance = 1.463746771812121
# Cluster 18: Largest intracluster distance = 1.4618697834943395
# Cluster 41: Largest intracluster distance = 1.4018486738104858
# Cluster 84: Largest intracluster distance = 1.409994850706792
# Cluster 71: Largest intracluster distance = 1.449502796396882
# Cluster 20: Largest intracluster distance = 1.4240555860439814
# Cluster 77: Largest intracluster distance = 1.4413092225076982
# Cluster 17: Largest intracluster distance = 1.4712522715509557
# Cluster 30: Largest intracluster distance = 1.4460460086334261
# Cluster 60: Largest intracluster distance = 1.4162406622732808
# Cluster 29: Largest intracluster distance = 1.441179614482161
# Cluster 43: Largest intracluster distance = 1.4537895699421333
# Cluster 50: Largest intracluster distance = 1.4005151423237363
# Cluster 67: Largest intracluster distance = 1.3228261872389369
# Cluster 82: Largest intracluster distance = 1.396735905412951
# Cluster 1: Largest intracluster distance = 1.4461175500276893
# Cluster 45: Largest intracluster distance = 1.3788717068504208
# Cluster 24: Largest intracluster distance = 1.4703083940032042
# Cluster 13: Largest intracluster distance = 1.3624112675497504
# Cluster 36: Largest intracluster distance = 1.4092363754127768
# Cluster 55: Largest intracluster distance = 1.4263476275819917
# Cluster 83: Largest intracluster distance = 1.2999716217181911
# Cluster 14: Largest intracluster distance = 1.4221114164771818
# Cluster 3: Largest intracluster distance = 1.382766190330147
# Cluster 81: Largest intracluster distance = 1.4374572904750536
# Cluster 44: Largest intracluster distance = 1.49608212166845
# Cluster 66: Largest intracluster distance = 1.441354929210445
# Cluster 31: Largest intracluster distance = 1.4328962150539422
# Cluster 80: Largest intracluster distance = 1.5752704255106578
# Cluster 40: Largest intracluster distance = 1.3451421214897805
# Cluster 78: Largest intracluster distance = 1.4438806306785275
# Cluster 39: Largest intracluster distance = 1.4362128599274955
# Cluster 38: Largest intracluster distance = 1.5018041400784998
# Cluster 58: Largest intracluster distance = 1.3870115426969154
# Cluster 53: Largest intracluster distance = 1.501513556370074
# Cluster 98: Largest intracluster distance = 1.4830663718535482
# Cluster 10: Largest intracluster distance = 1.4275016002090761
# Cluster 94: Largest intracluster distance = 1.4620288120085099
# Cluster 95: Largest intracluster distance = 1.4907587437349044
# Cluster 62: Largest intracluster distance = 1.4668966586174668
# Cluster 2: Largest intracluster distance = 1.49546245219743
# Cluster 15: Largest intracluster distance = 1.4247273410970205
# Cluster 73: Largest intracluster distance = 1.4739373832072982
# Cluster 26: Largest intracluster distance = 1.5357027677167152
# Cluster 42: Largest intracluster distance = 1.4203741031696935
# Cluster 16: Largest intracluster distance = 1.3939011854621879
# Cluster 61: Largest intracluster distance = 1.446973425930198
# Cluster 74: Largest intracluster distance = 1.547695754514047
# Cluster 70: Largest intracluster distance = 1.4202429970306887
# Cluster 32: Largest intracluster distance = 1.4415908340571784
# Cluster 54: Largest intracluster distance = 1.415500535209397
# Cluster 47: Largest intracluster distance = 1.3709704605951893
# Cluster 56: Largest intracluster distance = 1.4509655723656847
# Cluster 19: Largest intracluster distance = 1.4824877316382707
# Cluster 64: Largest intracluster distance = 1.5031926402211033
# Cluster 57: Largest intracluster distance = 1.3339352174895625
# Cluster 33: Largest intracluster distance = 1.381223076879008
# Cluster 6: Largest intracluster distance = 1.4491077641480867
# Cluster 34: Largest intracluster distance = 1.465882823182878
# Cluster 12: Largest intracluster distance = 1.5029726105800052
# Cluster 86: Largest intracluster distance = 1.4113496175660167
# Cluster 85: Largest intracluster distance = 1.4332936320165266
# Cluster 8: Largest intracluster distance = 1.4391012659624556
# Cluster 4: Largest intracluster distance = 1.4822977697794115
# Cluster 93: Largest intracluster distance = 1.3858929853639046
# Cluster 0: Largest intracluster distance = 1.5464191283582327
# Cluster 91: Largest intracluster distance = 1.3877888499678386
# Cluster 21: Largest intracluster distance = 1.530819498932332
# Cluster 59: Largest intracluster distance = 1.503068518109771
# Cluster 23: Largest intracluster distance = 1.5095315308521735
# Cluster 9: Largest intracluster distance = 1.436858548241194
# Cluster 92: Largest intracluster distance = 1.4946219605276234
# Cluster 22: Largest intracluster distance = 1.4184070811314176
# Cluster 75: Largest intracluster distance = 1.3839224243328925
# Cluster 96: Largest intracluster distance = 1.4856120515880062
# Cluster 35: Largest intracluster distance = 1.444971628863484
# Cluster 5: Largest intracluster distance = 1.3935895989949452
# Cluster 99: Largest intracluster distance = 1.3162529222156447
# Cluster 87: Largest intracluster distance = 1.4307767876556132
# Cluster 11: Largest intracluster distance = 1.3950360460474325
# Cluster 46: Largest intracluster distance = 1.4447804013022556
# Cluster 63: Largest intracluster distance = 1.4014942805716306
# Cluster 65: Largest intracluster distance = 1.4444343482183597
# Cluster 89: Largest intracluster distance = 1.4178816514986452
# Cluster 37: Largest intracluster distance = 1.4418160615682132
# Cluster 27: Largest intracluster distance = 1.4437118729291882
# Cluster 48: Largest intracluster distance = 1.3781416606541406
# Cluster 51: Largest intracluster distance = 1.3782187507324466

# %%
# Given a word, find the cluster to which it belongs

def find_word_cluster(word, clusters):
    for label, words in clusters.items():
        if word in words:
            return label
    return None

# Example usage
target_word = 'paris'
target_cluster = find_word_cluster(target_word, clusters)
if target_cluster is not None:
    print(f"The word '{target_word}' belongs to cluster {target_cluster}.")
else:
    print(f"The word '{target_word}' does not belong to any cluster.")
# Out:
# The word 'paris' belongs to cluster 25.

# %% [markdown]
# This function implements the exponential mechanism from differential privacy to probabilistically select a cluster from a given set of clusters. The selection is based on the negative distance between the clusters, with the goal of selecting a cluster that is similar to a specified target cluster. The function takes as input the clusters, a matrix of distances between clusters, the label of the target cluster, and a privacy parameter epsilon. It calculates the utility of each cluster as the negative distance from the target cluster, then computes the selection probabilities using the exponential mechanism, taking into account the sensitivity of the distance metric. Finally, it selects and returns a cluster based on these probabilities. The example usage demonstrates how to use this function to select a cluster similar to a given target cluster.

# %%
def exponential_mechanism(clusters, distances, selected_label, epsilon=1):
    # Calculate the utilities for each cluster based on the negative distance to the selected cluster
    utilities = [-distances[selected_label, label] for label in clusters.keys()]

    # Calculate the sensitivity
    sensitivity = np.max(distances)

    # Compute the probabilities for each cluster using the exponential mechanism
    probabilities = np.exp(np.array(utilities) * epsilon / (2 * sensitivity))
    probabilities /= np.sum(probabilities)

    # Select a cluster probabilistically
    selected_cluster = np.random.choice(list(clusters.keys()), p=probabilities)

    return selected_cluster

# Example usage
selected_label = target_cluster  # The label of the cluster for which we want to select a similar cluster
selected_cluster = exponential_mechanism(clusters, max_distances, selected_label, epsilon=20)
print(f"Selected cluster: {selected_cluster}")
# Out:
# Selected cluster: 25

# %% [markdown]
# This code defines a function `exponential_mechanism_for_word` that uses the exponential mechanism from differential privacy to probabilistically select a word from a given cluster. The selection is based on the negative cosine distance between the target word's embedding and the embeddings of the words in the cluster. The function calculates the utilities for each word in the cluster, computes the probabilities using the exponential mechanism, and then randomly selects a word based on these probabilities. The sensitivity parameter (`sensitivity_intra[target_cluster]`) controls how much the selection is influenced by the distances. The function returns the index of the selected word, which is then used to retrieve the selected word from the cluster.

# %%
def exponential_mechanism_for_word(selected_cluster_embeddings, target_word_embedding, sensitivity_intra, epsilon=1):
    # Calculate the utilities for each word in the cluster
    utilities = [-cosine(target_word_embedding, word_embedding) for word_embedding in selected_cluster_embeddings]

    # Calculate the probabilities using the exponential mechanism
    probabilities = np.exp(epsilon * np.array(utilities) / (2 * sensitivity_intra))
    probabilities /= np.sum(probabilities)

    # Randomly select a word based on the probabilities
    selected_index = np.random.choice(range(len(selected_cluster_embeddings)), p=probabilities)
    return selected_index

# Example usage
target_word_embedding = normalized_embeddings[target_word]
selected_cluster_embeddings = [normalized_embeddings[word] for word in clusters[selected_cluster]]

selected_index = exponential_mechanism_for_word(selected_cluster_embeddings, target_word_embedding, sensitivity_intra[selected_cluster], epsilon=1)
selected_word = clusters[selected_cluster][selected_index]

print(f"Selected word: {selected_word}")
# Out:
# Selected word: macedonia
